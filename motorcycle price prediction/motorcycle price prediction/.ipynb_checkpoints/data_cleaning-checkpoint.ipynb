# %% [markdown]
# ## 0. Import một số thư viện cần thiết

# %%
import pandas as pd
import numpy as np

# %%
PATH = 'D:/motorcycle price prediction/data/moto_crawl.csv'
SAVE_PATH = 'D:/motorcycle price prediction/data/moto_cleaned.csv'

# %% [markdown]
# ## 1. Tạo dataframe từ dữ liệu thô với các header tương ứng

# %%
# Tạo các header tương ứng với các cột thuộc tính
headers = ["Hang_xe", "Nam_dang_ky", "Tinh_trang_xe", 
          "Dung_tich_xe", "Dong_xe", "So_km_da_di"
          ,"Loai_xe", "Gia_xe"]

df = pd.read_csv(PATH, names=headers)

# Hiển thị 10 dòng đầu của dataframe
df.head(10)
# Out:
#    Hang_xe Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe So_km_da_di  \
# 0    Honda        2018      Đãsửdụng         Null  AirBlade       38000
# 1    Honda        2020      Đãsửdụng    100-175cc    MSX125       10000
# 2   Yamaha        2024      Đãsửdụng    100-175cc       XSR         340
# 3    Honda        1999      Đãsửdụng    100-175cc      Wave      123456
# 4  VinFast        2025           Mới         Null  Dòngkhác           0
# 5    Honda        2020      Đãsửdụng    100-175cc    Vision        9000
# 6    Honda        2017      Đãsửdụng         Null    Winner        5000
# 7    Honda        2023      Đãsửdụng    100-175cc      Lead        7000
# 8    Honda        2004      Đãsửdụng         Null     Dylan        3000
# 9  Piaggio        2014      Đãsửdụng    100-175cc   Liberty       20000
#
#        Loai_xe       Gia_xe
# 0        Tayga  26.000.000đ
# 1  Taycôn/Moto  20.000.000đ
# 2  Taycôn/Moto  79.000.000đ
# 3         Xesố  22.500.000đ
# 4        Tayga  14.990.000đ
# 5        Tayga  28.500.000đ
# 6         Xesố   6.950.000đ
# 7        Tayga  49.800.000đ
# 8        Tayga  35.000.000đ
# 9        Tayga  13.000.000đ

# %%
# Kiểm tra số chiều của bộ dữ liệu ban đầu
df.shape
# Out:
# (19297, 8)

# %%
# Kiểm tra kiểu dữ liệu của các thuộc tính
df.dtypes
# Out:
# Hang_xe          object
# Nam_dang_ky      object
# Tinh_trang_xe    object
# Dung_tich_xe     object
# Dong_xe          object
# So_km_da_di      object
# Loai_xe          object
# Gia_xe           object
# dtype: object

# %%
# Kiểm tra dữ liệu bị trùng
df.duplicated().sum()
# Out:
# 943

# %%
# Xóa các dòng có dữ liệu bị trùng
df = df.drop_duplicates(keep='first')

# Số chiều của bộ dữ liệu sau khi xóa các dữ liệu trùng
df.shape
# Out:
# (18354, 8)

# %%
# Thay đổi các giá trị từ Null sang NaN
df = df.replace("Null", np.nan)

df.head(10)
# Out:
#    Hang_xe Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe So_km_da_di  \
# 0    Honda        2018      Đãsửdụng          NaN  AirBlade       38000
# 1    Honda        2020      Đãsửdụng    100-175cc    MSX125       10000
# 2   Yamaha        2024      Đãsửdụng    100-175cc       XSR         340
# 3    Honda        1999      Đãsửdụng    100-175cc      Wave      123456
# 4  VinFast        2025           Mới          NaN  Dòngkhác           0
# 5    Honda        2020      Đãsửdụng    100-175cc    Vision        9000
# 6    Honda        2017      Đãsửdụng          NaN    Winner        5000
# 7    Honda        2023      Đãsửdụng    100-175cc      Lead        7000
# 8    Honda        2004      Đãsửdụng          NaN     Dylan        3000
# 9  Piaggio        2014      Đãsửdụng    100-175cc   Liberty       20000
#
#        Loai_xe       Gia_xe
# 0        Tayga  26.000.000đ
# 1  Taycôn/Moto  20.000.000đ
# 2  Taycôn/Moto  79.000.000đ
# 3         Xesố  22.500.000đ
# 4        Tayga  14.990.000đ
# 5        Tayga  28.500.000đ
# 6         Xesố   6.950.000đ
# 7        Tayga  49.800.000đ
# 8        Tayga  35.000.000đ
# 9        Tayga  13.000.000đ

# %%
# Kiểm tra các giá trị null
df.isna().sum()
# Out:
# Hang_xe             0
# Nam_dang_ky         0
# Tinh_trang_xe       0
# Dung_tich_xe     4635
# Dong_xe             0
# So_km_da_di       169
# Loai_xe             0
# Gia_xe              0
# dtype: int64

# %% [markdown]
# ## 2. Làm sạch dữ liệu với cột Hang_xe

# %%
# Xem các hãng xe có trong bộ dữ liệu
print(f'Tổng số hãng xe: {len(set(df["Hang_xe"]))}')

hang_xe = list(set(df["Hang_xe"]))

print(f'Các loại xe:')

for i, xe in enumerate(hang_xe):
    print(i + 1, xe)
# Out:
# Tổng số hãng xe: 38
# Các loại xe:
# 1 Honda
# 2 Brixton
# 3 Piaggio
# 4 Bazan
# 5 Kymco
# 6 Yamaha
# 7 MotoGuzzi
# 8 Hãngkhác
# 9 Kengo
# 10 Halim
# 11 Victory
# 12 Hyosung
# 13 Ducati
# 14 Detech
# 15 Vento
# 16 RegalRaptor
# 17 RoyalEnfield
# 18 HarleyDavidson
# 19 Peugeot
# 20 Suzuki
# 21 Daelim
# 22 BMW
# 23 Aprilia
# 24 Sanda
# 25 Triumph
# 26 Visitor
# 27 Kawasaki
# 28 SYM
# 29 GPX
# 30 EuroReibel
# 31 Taya
# 32 Benelli
# 33 MVAgusta
# 34 Sachs
# 35 KTM
# 36 RebelUSA
# 37 VinFast
# 38 Nioshima

# %%
# Xem giá trị "Hãngkhác" trong các loại xe
df[df["Hang_xe"] == "Hãngkhác"]
# Out:
#         Hang_xe Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe So_km_da_di  \
# 38     Hãngkhác        2018      Đãsửdụng     50-100cc  Dòngkhác        1000
# 166    Hãngkhác        2019      Đãsửdụng     Dưới50cc  Dòngkhác       10000
# 240    Hãngkhác        2021      Đãsửdụng          NaN  Dòngkhác       22222
# 288    Hãngkhác        2008      Đãsửdụng    100-175cc  Dòngkhác       36852
# 348    Hãngkhác        2019      Đãsửdụng     Dưới50cc  Dòngkhác        7000
# ...         ...         ...           ...          ...       ...         ...
# 19105  Hãngkhác        2016      Đãsửdụng          NaN  Dòngkhác        1234
# 19201  Hãngkhác        2023      Đãsửdụng          NaN  Dòngkhác      100000
# 19204  Hãngkhác        2012      Đãsửdụng    100-175cc  Dòngkhác           2
# 19218  Hãngkhác        2006      Đãsửdụng     50-100cc  Dòngkhác       12345
# 19272  Hãngkhác        2024      Đãsửdụng     Dưới50cc  Dòngkhác           9
#
#            Loai_xe       Gia_xe
# 38            Xesố   2.500.000đ
# 166          Tayga   7.600.000đ
# 240          Tayga   8.800.000đ
# 288           Xesố   5.200.000đ
# 348           Xesố   8.800.000đ
# ...            ...          ...
# 19105         Xesố   8.600.000đ
# 19201         Xesố  11.000.000đ
# 19204  Taycôn/Moto  16.800.000đ
# 19218         Xesố   4.500.000đ
# 19272        Tayga  16.800.000đ
#
# [426 rows x 8 columns]

# %% [markdown]
# Các giá trị "Hãngkhác" đều có dòng không rõ, giá trị dao động của chúng có thể tùy thuộc vào các trường dữ liệu khác, và cũng chiếm một số lượng khá lớn (426 dòng), do đó ta sẽ không loại bỏ chúng, mà chỉ thay tên thành "Hãng khác"

# %%
df['Hang_xe'] = df['Hang_xe'].replace(["Hãngkhác"], "Hãng khác")

# %% [markdown]
# ## 3. Làm sạch dữ liệu với cột Nam_dang_ky

# %% [markdown]
# Với cột Nam_dang_ky, ta có thể tạo thêm một cột mới chứa thông tin về tuổi của xe tính đến thời điểm hiện tại bằng cách lấy năm hiện tại (2025) trừ đi năm đăng ký xe

# %%
# Xem các năm đăng ký xe có trong bộ dữ liệu
print("Các năm đăng ký: ")

years = list(set(df['Nam_dang_ky']))

for i, year in enumerate(years):
    print(f'{i + 1}. {year}')
# Out:
# Các năm đăng ký:
# 1. 2010
# 2. 1986
# 3. 1992
# 4. 1987
# 5. 2015
# 6. 2014
# 7. 1983
# 8. 2025
# 9. 1988
# 10. 2002
# 11. 2012
# 12. 1990
# 13. 1994
# 14. 1997
# 15. 1982
# 16. 1991
# 17. 2004
# 18. 1985
# 19. 1989
# 20. 2005
# 21. 1993
# 22. 1999
# 23. 1984
# 24. 1995
# 25. 2003
# 26. 1996
# 27. trướcnăm1980
# 28. 2018
# 29. 2022
# 30. 2000
# 31. 2009
# 32. 2024
# 33. 2008
# 34. 2007
# 35. 1998
# 36. 2020
# 37. 2011
# 38. 2001
# 39. 1981
# 40. 2013
# 41. 2021
# 42. 2016
# 43. 2023
# 44. 2006
# 45. 2019
# 46. 2017

# %% [markdown]
# Để quy về tuổi của xe, ta cần chuyển kiểu dữ liệu của cột năm đăng ký xe về kiểu dữ liệu số nguyên int

# %%
# Chuẩn hóa dữ liệu 'trướcnăm1980' thành 1980
df['Nam_dang_ky'] = df['Nam_dang_ky'].replace(['trướcnăm1980'], '1980')

years = list(set(df['Nam_dang_ky']))

for i, year in enumerate(years):
    print(f'{i + 1}. {year}')
# Out:
# 1. 2010
# 2. 1986
# 3. 1992
# 4. 1987
# 5. 2015
# 6. 2014
# 7. 1983
# 8. 2025
# 9. 1988
# 10. 2002
# 11. 2012
# 12. 1990
# 13. 1994
# 14. 1997
# 15. 1982
# 16. 1991
# 17. 2004
# 18. 1985
# 19. 1989
# 20. 2005
# 21. 1993
# 22. 1999
# 23. 1984
# 24. 1995
# 25. 2003
# 26. 1996
# 27. 2018
# 28. 2022
# 29. 2000
# 30. 2009
# 31. 2024
# 32. 2008
# 33. 1980
# 34. 2007
# 35. 1998
# 36. 2020
# 37. 2011
# 38. 2001
# 39. 1981
# 40. 2013
# 41. 2021
# 42. 2016
# 43. 2023
# 44. 2006
# 45. 2019
# 46. 2017

# %%
# Thêm cột Tuoi_xe từ cột Nam_dang_ky
THIS_YEAR = 2025

df["Nam_dang_ky"] = df["Nam_dang_ky"].astype(int)

df.insert(1,'Tuoi_xe', THIS_YEAR - df["Nam_dang_ky"])
df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe  \
# 0    Honda        7         2018      Đãsửdụng          NaN  AirBlade
# 1    Honda        5         2020      Đãsửdụng    100-175cc    MSX125
# 2   Yamaha        1         2024      Đãsửdụng    100-175cc       XSR
# 3    Honda       26         1999      Đãsửdụng    100-175cc      Wave
# 4  VinFast        0         2025           Mới          NaN  Dòngkhác
# 5    Honda        5         2020      Đãsửdụng    100-175cc    Vision
# 6    Honda        8         2017      Đãsửdụng          NaN    Winner
# 7    Honda        2         2023      Đãsửdụng    100-175cc      Lead
# 8    Honda       21         2004      Đãsửdụng          NaN     Dylan
# 9  Piaggio       11         2014      Đãsửdụng    100-175cc   Liberty
#
#   So_km_da_di      Loai_xe       Gia_xe
# 0       38000        Tayga  26.000.000đ
# 1       10000  Taycôn/Moto  20.000.000đ
# 2         340  Taycôn/Moto  79.000.000đ
# 3      123456         Xesố  22.500.000đ
# 4           0        Tayga  14.990.000đ
# 5        9000        Tayga  28.500.000đ
# 6        5000         Xesố   6.950.000đ
# 7        7000        Tayga  49.800.000đ
# 8        3000        Tayga  35.000.000đ
# 9       20000        Tayga  13.000.000đ

# %% [markdown]
# ## 4. Làm sạch dữ liệu với cột Tinh_trang_xe

# %%
# Xem các tình trạng xe có trong bộ dữ liệu
df["Tinh_trang_xe"].value_counts()
# Out:
# Tinh_trang_xe
# Đãsửdụng    18167
# Mới           187
# Name: count, dtype: int64

# %%
# Xem các xe có tình trạng sử dụng là mới
df[df["Tinh_trang_xe"].apply(lambda x : "Mới" in x)]
# Out:
#          Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe  \
# 4        VinFast        0         2025           Mới          NaN  Dòngkhác
# 36       VinFast        1         2024           Mới          NaN    KlaraS
# 41         Honda        1         2024           Mới    Trên175cc   WinnerX
# 42       VinFast        0         2025           Mới          NaN    KlaraS
# 124        Honda        1         2024           Mới    Trên175cc    Winner
# ...          ...      ...          ...           ...          ...       ...
# 18472  Hãng khác        3         2022           Mới     Dưới50cc  Dòngkhác
# 18612     Yamaha        1         2024           Mới    100-175cc   Exciter
# 18656      Honda        0         2025           Mới    100-175cc      Wave
# 18998      Honda       13         2012           Mới          NaN        SH
# 19013     Yamaha        5         2020           Mới    100-175cc        FZ
#
#       So_km_da_di      Loai_xe        Gia_xe
# 4               0        Tayga   14.990.000đ
# 36              0        Tayga   42.900.000đ
# 41            NaN        Tayga   38.850.000đ
# 42              0        Tayga   42.900.000đ
# 124           NaN  Taycôn/Moto   35.250.000đ
# ...           ...          ...           ...
# 18472         NaN         Xesố   10.000.000đ
# 18612         NaN  Taycôn/Moto   43.000.000đ
# 18656         NaN         Xesố   17.500.000đ
# 18998       22000        Tayga  240.000.000đ
# 19013         NaN  Taycôn/Moto   45.000.000đ
#
# [187 rows x 9 columns]

# %%
# Thay thế số km đã đi được của các xe này thành 0
df['So_km_da_di'] = np.where(df['Tinh_trang_xe'].apply(lambda x: "Mới" in x)\
                             , 0, df['So_km_da_di'])

df[df["Tinh_trang_xe"].apply(lambda x : "Mới" in x)]
# Out:
#          Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe  \
# 4        VinFast        0         2025           Mới          NaN  Dòngkhác
# 36       VinFast        1         2024           Mới          NaN    KlaraS
# 41         Honda        1         2024           Mới    Trên175cc   WinnerX
# 42       VinFast        0         2025           Mới          NaN    KlaraS
# 124        Honda        1         2024           Mới    Trên175cc    Winner
# ...          ...      ...          ...           ...          ...       ...
# 18472  Hãng khác        3         2022           Mới     Dưới50cc  Dòngkhác
# 18612     Yamaha        1         2024           Mới    100-175cc   Exciter
# 18656      Honda        0         2025           Mới    100-175cc      Wave
# 18998      Honda       13         2012           Mới          NaN        SH
# 19013     Yamaha        5         2020           Mới    100-175cc        FZ
#
#       So_km_da_di      Loai_xe        Gia_xe
# 4               0        Tayga   14.990.000đ
# 36              0        Tayga   42.900.000đ
# 41              0        Tayga   38.850.000đ
# 42              0        Tayga   42.900.000đ
# 124             0  Taycôn/Moto   35.250.000đ
# ...           ...          ...           ...
# 18472           0         Xesố   10.000.000đ
# 18612           0  Taycôn/Moto   43.000.000đ
# 18656           0         Xesố   17.500.000đ
# 18998           0        Tayga  240.000.000đ
# 19013           0  Taycôn/Moto   45.000.000đ
#
# [187 rows x 9 columns]

# %%
# Thay đổi dữ liệu từ 'Đãsửdụng' thành 'Đã sử dụng'
df['Tinh_trang_xe'] = df['Tinh_trang_xe'].replace(['Đãsửdụng' ], 'Đã sử dụng')
df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe Dung_tich_xe   Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng          NaN  AirBlade
# 1    Honda        5         2020    Đã sử dụng    100-175cc    MSX125
# 2   Yamaha        1         2024    Đã sử dụng    100-175cc       XSR
# 3    Honda       26         1999    Đã sử dụng    100-175cc      Wave
# 4  VinFast        0         2025           Mới          NaN  Dòngkhác
# 5    Honda        5         2020    Đã sử dụng    100-175cc    Vision
# 6    Honda        8         2017    Đã sử dụng          NaN    Winner
# 7    Honda        2         2023    Đã sử dụng    100-175cc      Lead
# 8    Honda       21         2004    Đã sử dụng          NaN     Dylan
# 9  Piaggio       11         2014    Đã sử dụng    100-175cc   Liberty
#
#   So_km_da_di      Loai_xe       Gia_xe
# 0       38000        Tayga  26.000.000đ
# 1       10000  Taycôn/Moto  20.000.000đ
# 2         340  Taycôn/Moto  79.000.000đ
# 3      123456         Xesố  22.500.000đ
# 4           0        Tayga  14.990.000đ
# 5        9000        Tayga  28.500.000đ
# 6        5000         Xesố   6.950.000đ
# 7        7000        Tayga  49.800.000đ
# 8        3000        Tayga  35.000.000đ
# 9       20000        Tayga  13.000.000đ

# %% [markdown]
# ## 5. Làm sạch dữ liệu với cột Dung_tich_xe

# %%
# Xem các dung tích xe có trong bộ dữ liệu
motor_caps = list(set(df['Dung_tich_xe']))

print("Phân loại dung tích xe:")

for i, cap in enumerate(motor_caps):
    print(f"Loại {i + 1}: {cap}")
# Out:
# Phân loại dung tích xe:
# Loại 1: Dưới50cc
# Loại 2: 100-175cc
# Loại 3: 50-100cc
# Loại 4: Khôngbiếtrõ
# Loại 5: Trên175cc
# Loại 6: nan

# %%
df["Dung_tich_xe"].value_counts()
# Out:
# Dung_tich_xe
# 100-175cc      11743
# 50-100cc         796
# Dưới50cc         649
# Trên175cc        509
# Khôngbiếtrõ       22
# Name: count, dtype: int64

# %% [markdown]
# Ta sẽ tách các cụm từ ra thành các từ rõ ràng như 100 - 175 cc, Trên 175 cc, 50 - 100 cc, Dưới 50 cc, Không biết rõ

# %%
# Thay đổi dữ liệu từ 'Dưới50cc', '50-100cc', '100-175cc', 'Trên175cc', 'Khôngbiếtrõ' thành 'Dưới 50cc', '50 - 100cc', '100 - 175cc', 'Trên 175cc', 'Không biết rõ'
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace(['Dưới50cc'], 'Dưới 50 cc')
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace(['50-100cc'], '50 - 100 cc')
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace(['100-175cc'], '100 - 175 cc')
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace(['Trên175cc'], 'Trên 175 cc')
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace(['Khôngbiếtrõ'], 'Không biết rõ')
df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe  Dung_tich_xe   Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng           NaN  AirBlade
# 1    Honda        5         2020    Đã sử dụng  100 - 175 cc    MSX125
# 2   Yamaha        1         2024    Đã sử dụng  100 - 175 cc       XSR
# 3    Honda       26         1999    Đã sử dụng  100 - 175 cc      Wave
# 4  VinFast        0         2025           Mới           NaN  Dòngkhác
# 5    Honda        5         2020    Đã sử dụng  100 - 175 cc    Vision
# 6    Honda        8         2017    Đã sử dụng           NaN    Winner
# 7    Honda        2         2023    Đã sử dụng  100 - 175 cc      Lead
# 8    Honda       21         2004    Đã sử dụng           NaN     Dylan
# 9  Piaggio       11         2014    Đã sử dụng  100 - 175 cc   Liberty
#
#   So_km_da_di      Loai_xe       Gia_xe
# 0       38000        Tayga  26.000.000đ
# 1       10000  Taycôn/Moto  20.000.000đ
# 2         340  Taycôn/Moto  79.000.000đ
# 3      123456         Xesố  22.500.000đ
# 4           0        Tayga  14.990.000đ
# 5        9000        Tayga  28.500.000đ
# 6        5000         Xesố   6.950.000đ
# 7        7000        Tayga  49.800.000đ
# 8        3000        Tayga  35.000.000đ
# 9       20000        Tayga  13.000.000đ

# %%
# Kiểm tra giá trị null của dung tích xe
df[df['Dung_tich_xe'].isnull()].shape
# Out:
# (4635, 9)

# %% [markdown]
# Nhận thấy, số lượng giá trị null của dung tích xe là quá lớn (4635), nên ta sẽ thay thế giá trị null bằng "Không biết rõ" đối với các giá trị rỗng của dung tích xe

# %%
df['Dung_tich_xe'] = df['Dung_tich_xe'].replace([np.nan], 'Không biết rõ')

# Kiểm tra lại giá trị null sau khi đã được thay bằng giá trị "Không biết rõ"
df[df['Dung_tich_xe'].isnull()].shape
# Out:
# (0, 9)

# %%
df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe   Dung_tich_xe   Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng  Không biết rõ  AirBlade
# 1    Honda        5         2020    Đã sử dụng   100 - 175 cc    MSX125
# 2   Yamaha        1         2024    Đã sử dụng   100 - 175 cc       XSR
# 3    Honda       26         1999    Đã sử dụng   100 - 175 cc      Wave
# 4  VinFast        0         2025           Mới  Không biết rõ  Dòngkhác
# 5    Honda        5         2020    Đã sử dụng   100 - 175 cc    Vision
# 6    Honda        8         2017    Đã sử dụng  Không biết rõ    Winner
# 7    Honda        2         2023    Đã sử dụng   100 - 175 cc      Lead
# 8    Honda       21         2004    Đã sử dụng  Không biết rõ     Dylan
# 9  Piaggio       11         2014    Đã sử dụng   100 - 175 cc   Liberty
#
#   So_km_da_di      Loai_xe       Gia_xe
# 0       38000        Tayga  26.000.000đ
# 1       10000  Taycôn/Moto  20.000.000đ
# 2         340  Taycôn/Moto  79.000.000đ
# 3      123456         Xesố  22.500.000đ
# 4           0        Tayga  14.990.000đ
# 5        9000        Tayga  28.500.000đ
# 6        5000         Xesố   6.950.000đ
# 7        7000        Tayga  49.800.000đ
# 8        3000        Tayga  35.000.000đ
# 9       20000        Tayga  13.000.000đ

# %% [markdown]
# ## 6. Làm sạch dữ liệu với cột Dong_xe

# %%
# Xem các dòng xe có trong bộ dữ liệu
models = list(set(df["Dong_xe"]))

print("Các dòng xe:")
for i, model in enumerate(models):
    print(f"Dòng xe {i + 1}: {model}")
# Out:
# Các dòng xe:
# Dòng xe 1: Wolf
# Dòng xe 2: Elegant
# Dòng xe 3: LX
# Dòng xe 4: Cub
# Dòng xe 5: Demon150GR
# Dòng xe 6: Z900
# Dòng xe 7: Sprint
# Dòng xe 8: Giorno
# Dòng xe 9: PX
# Dòng xe 10: ADV150
# Dòng xe 11: RnineT
# Dòng xe 12: StreetScramber
# Dòng xe 13: R
# Dòng xe 14: RC200
# Dòng xe 15: 67
# Dòng xe 16: AirBlade
# Dòng xe 17: JockeyFi
# Dòng xe 18: Cello
# Dòng xe 19: Amigo
# Dòng xe 20: ADV160
# Dòng xe 21: Touring
# Dòng xe 22: RSV4RR
# Dòng xe 23: Django
# Dòng xe 24: Vulcan
# Dòng xe 25: LegendGentleman200
# Dòng xe 26: Smash
# Dòng xe 27: Xbike
# Dòng xe 28: Elite
# Dòng xe 29: VThunderXL
# Dòng xe 30: KlaraS
# Dòng xe 31: Scrambler
# Dòng xe 32: Angela
# Dòng xe 33: W800
# Dòng xe 34: Multistrada
# Dòng xe 35: Beverly
# Dòng xe 36: Liberty
# Dòng xe 37: FatBoy
# Dòng xe 38: Evo200
# Dòng xe 39: Legend150S
# Dòng xe 40: ZX10R
# Dòng xe 41: Venus
# Dòng xe 42: PG-1
# Dòng xe 43: Goebel
# Dòng xe 44: R1200
# Dòng xe 45: Star
# Dòng xe 46: Z650
# Dòng xe 47: Blade
# Dòng xe 48: VespaS125
# Dòng xe 49: FX125
# Dòng xe 50: Janus
# Dòng xe 51: Revo
# Dòng xe 52: CBR
# Dòng xe 53: Fiddle
# Dòng xe 54: V7
# Dòng xe 55: Z400
# Dòng xe 56: Z1000
# Dòng xe 57: PeopleSFi
# Dòng xe 58: CG125Fi
# Dòng xe 59: Scoopy
# Dòng xe 60: Viva
# Dòng xe 61: LikeFi
# Dòng xe 62: Shark
# Dòng xe 63: Symphony
# Dòng xe 64: Taurus
# Dòng xe 65: Vision
# Dòng xe 66: DayStar125Fi
# Dòng xe 67: Estrella
# Dòng xe 68: 1199panigale
# Dòng xe 69: Nouvo
# Dòng xe 70: LowRider
# Dòng xe 71: StreetTwin
# Dòng xe 72: Boss
# Dòng xe 73: KPR
# Dòng xe 74: CandyHi
# Dòng xe 75: Nova
# Dòng xe 76: Win
# Dòng xe 77: People16Fi
# Dòng xe 78: SH
# Dòng xe 79: Joyride
# Dòng xe 80: Interceptor650
# Dòng xe 81: Wave
# Dòng xe 82: Lead
# Dòng xe 83: Demon150GN
# Dòng xe 84: Acruzo
# Dòng xe 85: SandaBoss
# Dòng xe 86: Roadster
# Dòng xe 87: Nozza
# Dòng xe 88: VentoS
# Dòng xe 89: K-Pipe
# Dòng xe 90: PS
# Dòng xe 91: Duke690
# Dòng xe 92: RC390
# Dòng xe 93: Citi
# Dòng xe 94: Royal
# Dòng xe 95: GD
# Dòng xe 96: Avitor
# Dòng xe 97: Phoenix
# Dòng xe 98: Sport/Xipo
# Dòng xe 99: Versys
# Dòng xe 100: LikeMMC
# Dòng xe 101: Vario
# Dòng xe 102: S1000RR
# Dòng xe 103: Amici
# Dòng xe 104: GZ
# Dòng xe 105: @
# Dòng xe 106: Bullet500
# Dòng xe 107: Legend200
# Dòng xe 108: Click
# Dòng xe 109: CandyS
# Dòng xe 110: Latte
# Dòng xe 111: Superlow
# Dòng xe 112: 302R
# Dòng xe 113: Medley
# Dòng xe 114: Sapphire
# Dòng xe 115: Rebellian
# Dòng xe 116: Street
# Dòng xe 117: Z300
# Dòng xe 118: TNT
# Dòng xe 119: Bella
# Dòng xe 120: Future
# Dòng xe 121: Rock
# Dòng xe 122: MSX125
# Dòng xe 123: 48
# Dòng xe 124: MadAss
# Dòng xe 125: GN
# Dòng xe 126: Monster
# Dòng xe 127: Grande
# Dòng xe 128: SCR
# Dòng xe 129: Hypermotard
# Dòng xe 130: Luvias
# Dòng xe 131: CaffeNero
# Dòng xe 132: Softail
# Dòng xe 133: YAZ
# Dòng xe 134: Rebel
# Dòng xe 135: CB
# Dòng xe 136: Winner
# Dòng xe 137: W400
# Dòng xe 138: Ninja
# Dòng xe 139: Fly
# Dòng xe 140: Epicuro
# Dòng xe 141: FZ
# Dòng xe 142: Galaxy
# Dòng xe 143: EZ
# Dòng xe 144: Espero
# Dòng xe 145: Yass
# Dòng xe 146: C600
# Dòng xe 147: W175
# Dòng xe 148: Impulse
# Dòng xe 149: NioFi50cc
# Dòng xe 150: VS125
# Dòng xe 151: Vespa
# Dòng xe 152: Kawasaki
# Dòng xe 153: BN302
# Dòng xe 154: Sportster
# Dòng xe 155: Stinger
# Dòng xe 156: Dragster
# Dòng xe 157: Classic500
# Dòng xe 158: ET8
# Dòng xe 159: BX150
# Dòng xe 160: PCX
# Dòng xe 161: Freego
# Dòng xe 162: Primavera
# Dòng xe 163: Rebell
# Dòng xe 164: CD
# Dòng xe 165: GT
# Dòng xe 166: Best
# Dòng xe 167: TheonS
# Dòng xe 168: Z125
# Dòng xe 169: XSR
# Dòng xe 170: Hayate
# Dòng xe 171: Chaly
# Dòng xe 172: Magic
# Dòng xe 173: Dòngkhác
# Dòng xe 174: Attila
# Dòng xe 175: MT
# Dòng xe 176: Enjoy
# Dòng xe 177: Cuxi
# Dòng xe 178: Satria
# Dòng xe 179: Max
# Dòng xe 180: Nvx
# Dòng xe 181: TriumphBonnevilleT100
# Dòng xe 182: Zip
# Dòng xe 183: Shadow
# Dòng xe 184: Z800
# Dòng xe 185: Axelo
# Dòng xe 186: Elizabeth
# Dòng xe 187: WinnerX
# Dòng xe 188: Bonus
# Dòng xe 189: Crystal
# Dòng xe 190: Dylan
# Dòng xe 191: Sonic
# Dòng xe 192: Dream
# Dòng xe 193: S1000R
# Dòng xe 194: Mio
# Dòng xe 195: F3
# Dòng xe 196: T15
# Dòng xe 197: Duke390
# Dòng xe 198: TFX
# Dòng xe 199: Jupiter
# Dòng xe 200: YB125
# Dòng xe 201: Husky
# Dòng xe 202: TriumphTigerExplorerXC
# Dòng xe 203: Pepe
# Dòng xe 204: Sirius
# Dòng xe 205: TRK
# Dòng xe 206: BX125
# Dòng xe 207: Monkey
# Dòng xe 208: Exciter
# Dòng xe 209: R250
# Dòng xe 210: Duke200
# Dòng xe 211: XMAX
# Dòng xe 212: Daytona
# Dòng xe 213: SHMode
# Dòng xe 214: W650
# Dòng xe 215: EN
# Dòng xe 216: Spacy
# Dòng xe 217: Raider
# Dòng xe 218: GTS
# Dòng xe 219: Beat
# Dòng xe 220: GSX

# %%
# Thay đổi dữ liệu từ 'Dòngkhác'  thành 'Dòng khác'
df['Dong_xe'] = df['Dong_xe'].replace(['Dòngkhác'], "Dòng khác")

# Số chiều của dữ liệu dòng xe
df.shape
# Out:
# (18354, 9)

# %% [markdown]
# ## 7. Làm sạch dữ liệu với cột So_km_da_di

# %%
# Kiểm tra và xoá các giá trị null của số km đã đi
df[df['So_km_da_di'].isnull()].shape
df = df[df['So_km_da_di'].notna()]

# Ép kiểu dữ liệu sang kiểu int
df['So_km_da_di'] = df['So_km_da_di'].astype(int)

df['So_km_da_di'].dtypes
# Out:
# dtype('int32')

# %%
df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe   Dung_tich_xe    Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng  Không biết rõ   AirBlade
# 1    Honda        5         2020    Đã sử dụng   100 - 175 cc     MSX125
# 2   Yamaha        1         2024    Đã sử dụng   100 - 175 cc        XSR
# 3    Honda       26         1999    Đã sử dụng   100 - 175 cc       Wave
# 4  VinFast        0         2025           Mới  Không biết rõ  Dòng khác
# 5    Honda        5         2020    Đã sử dụng   100 - 175 cc     Vision
# 6    Honda        8         2017    Đã sử dụng  Không biết rõ     Winner
# 7    Honda        2         2023    Đã sử dụng   100 - 175 cc       Lead
# 8    Honda       21         2004    Đã sử dụng  Không biết rõ      Dylan
# 9  Piaggio       11         2014    Đã sử dụng   100 - 175 cc    Liberty
#
#    So_km_da_di      Loai_xe       Gia_xe
# 0        38000        Tayga  26.000.000đ
# 1        10000  Taycôn/Moto  20.000.000đ
# 2          340  Taycôn/Moto  79.000.000đ
# 3       123456         Xesố  22.500.000đ
# 4            0        Tayga  14.990.000đ
# 5         9000        Tayga  28.500.000đ
# 6         5000         Xesố   6.950.000đ
# 7         7000        Tayga  49.800.000đ
# 8         3000        Tayga  35.000.000đ
# 9        20000        Tayga  13.000.000đ

# %%
# Kiểm tra các giá trị của số km để đảm bảo không bị âm
df[df["So_km_da_di"] < 0]
# Out:
# Empty DataFrame
# Columns: [Hang_xe, Tuoi_xe, Nam_dang_ky, Tinh_trang_xe, Dung_tich_xe, Dong_xe, So_km_da_di, Loai_xe, Gia_xe]
# Index: []

# %% [markdown]
# ## 8. Làm sạch dữ liệu với cột Loai_xe

# %%
# Xem các loại xe có trong bộ dữ liệu
df["Loai_xe"]
# Out:
# 0              Tayga
# 1        Taycôn/Moto
# 2        Taycôn/Moto
# 3               Xesố
# 4              Tayga
#             ...
# 19291    Taycôn/Moto
# 19292    Taycôn/Moto
# 19293           Xesố
# 19295    Taycôn/Moto
# 19296    Taycôn/Moto
# Name: Loai_xe, Length: 18354, dtype: object

# %%
# Thay đổi dữ liệu từ 'Tayga', 'Taycôn/Moto', 'Xesố' thành 'Tay ga', 'Tay côn/Moto', 'Xe số'
df['Loai_xe'] = df['Loai_xe'].replace(['Tayga'], 'Tay ga')
df['Loai_xe'] = df['Loai_xe'].replace(['Taycôn/Moto'], 'Tay côn/Moto')
df['Loai_xe'] = df['Loai_xe'].replace(['Xesố'], 'Xe số')

df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe   Dung_tich_xe    Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng  Không biết rõ   AirBlade
# 1    Honda        5         2020    Đã sử dụng   100 - 175 cc     MSX125
# 2   Yamaha        1         2024    Đã sử dụng   100 - 175 cc        XSR
# 3    Honda       26         1999    Đã sử dụng   100 - 175 cc       Wave
# 4  VinFast        0         2025           Mới  Không biết rõ  Dòng khác
# 5    Honda        5         2020    Đã sử dụng   100 - 175 cc     Vision
# 6    Honda        8         2017    Đã sử dụng  Không biết rõ     Winner
# 7    Honda        2         2023    Đã sử dụng   100 - 175 cc       Lead
# 8    Honda       21         2004    Đã sử dụng  Không biết rõ      Dylan
# 9  Piaggio       11         2014    Đã sử dụng   100 - 175 cc    Liberty
#
#    So_km_da_di       Loai_xe       Gia_xe
# 0        38000        Tay ga  26.000.000đ
# 1        10000  Tay côn/Moto  20.000.000đ
# 2          340  Tay côn/Moto  79.000.000đ
# 3       123456         Xe số  22.500.000đ
# 4            0        Tay ga  14.990.000đ
# 5         9000        Tay ga  28.500.000đ
# 6         5000         Xe số   6.950.000đ
# 7         7000        Tay ga  49.800.000đ
# 8         3000        Tay ga  35.000.000đ
# 9        20000        Tay ga  13.000.000đ

# %% [markdown]
# ## 9. Làm sạch dữ liệu với cột Gia_xe

# %%
# Kiểm tra và loại bỏ các giá trị null của giá xe
df = df[df['Gia_xe'].notna()]

# Thay đổi các giá trị trong giá xe (loại bỏ ký tự đ ở cuối, bỏ các dấu .) và chuyển kiểu dữ liệu sang float
df["Gia_xe"] = df['Gia_xe'].apply(lambda x: x[:-1])
df["Gia_xe"] = df['Gia_xe'].apply(lambda x: x.replace('.', ''))
df['Gia_xe'] = df['Gia_xe'].astype(float)

df.head(10)
# Out:
#    Hang_xe  Tuoi_xe  Nam_dang_ky Tinh_trang_xe   Dung_tich_xe    Dong_xe  \
# 0    Honda        7         2018    Đã sử dụng  Không biết rõ   AirBlade
# 1    Honda        5         2020    Đã sử dụng   100 - 175 cc     MSX125
# 2   Yamaha        1         2024    Đã sử dụng   100 - 175 cc        XSR
# 3    Honda       26         1999    Đã sử dụng   100 - 175 cc       Wave
# 4  VinFast        0         2025           Mới  Không biết rõ  Dòng khác
# 5    Honda        5         2020    Đã sử dụng   100 - 175 cc     Vision
# 6    Honda        8         2017    Đã sử dụng  Không biết rõ     Winner
# 7    Honda        2         2023    Đã sử dụng   100 - 175 cc       Lead
# 8    Honda       21         2004    Đã sử dụng  Không biết rõ      Dylan
# 9  Piaggio       11         2014    Đã sử dụng   100 - 175 cc    Liberty
#
#    So_km_da_di       Loai_xe      Gia_xe
# 0        38000        Tay ga  26000000.0
# 1        10000  Tay côn/Moto  20000000.0
# 2          340  Tay côn/Moto  79000000.0
# 3       123456         Xe số  22500000.0
# 4            0        Tay ga  14990000.0
# 5         9000        Tay ga  28500000.0
# 6         5000         Xe số   6950000.0
# 7         7000        Tay ga  49800000.0
# 8         3000        Tay ga  35000000.0
# 9        20000        Tay ga  13000000.0

# %%
# Kiểm tra số chiều của bộ dữ liệu sau khi làm sạch
df.shape
# Out:
# (18354, 9)

# %%
# Kiểm tra bộ dữ liệu sau khi làm sạch
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18354 entries, 0 to 19296
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hang_xe        18354 non-null  object
#  1   Tuoi_xe        18354 non-null  int32
#  2   Nam_dang_ky    18354 non-null  int32
#  3   Tinh_trang_xe  18354 non-null  object
#  4   Dung_tich_xe   18354 non-null  object
#  5   Dong_xe        18354 non-null  object
#  6   So_km_da_di    18354 non-null  int32
#  7   Loai_xe        18354 non-null  object
#  8   Gia_xe         18354 non-null  float64
# dtypes: float64(1), int32(3), object(5)
# memory usage: 1.2+ MB

# %%
# Kiểm tra các giá trị null sau khi làm sạch
df.isna().sum()
# Out:
# Hang_xe          0
# Tuoi_xe          0
# Nam_dang_ky      0
# Tinh_trang_xe    0
# Dung_tich_xe     0
# Dong_xe          0
# So_km_da_di      0
# Loai_xe          0
# Gia_xe           0
# dtype: int64

# %%
# Kiểm tra các giá trị trùng lặp sau khi làm sạch
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 10. Lưu lại dữ liệu đã được làm sạch vào một file mới

# %%
df.to_csv(SAVE_PATH, index=False, encoding='utf-8-sig')
